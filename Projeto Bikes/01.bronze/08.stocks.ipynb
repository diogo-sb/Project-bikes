# %%
# Definir pastas do projetos em variaveis para facilitar
bronze_path   = '/Volumes/bikestore/default/bikestore/bronze/'
silver_path   = '/Volumes/bikestore/default/bikestore/silver/'
gold_path     = '/Volumes/bikestore/default/bikestore/gold/'
resource_path = '/Volumes/bikestore/default/bikestore/resource/origem/'
#resource_path_volume = '/Volumes/infinitybigdata/azure/bikestore_resource/origem/'

# %%
display(dbutils.fs.ls(resource_path))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/bikestore/default/bikestore/resource/origem/brands.csv</td><td>brands.csv</td><td>120</td><td>1784852559000</td></tr><tr><td>dbfs:/Volumes/bikestore/default/bikestore/resource/origem/categories.csv</td><td>categories.csv</td><td>162</td><td>1784852559000</td></tr><tr><td>dbfs:/Volumes/bikestore/default/bikestore/resource/origem/customers.csv</td><td>customers.csv</td><td>127671</td><td>1784852559000</td></tr><tr><td>dbfs:/Volumes/bikestore/default/bikestore/resource/origem/order_items.csv</td><td>order_items.csv</td><td>112937</td><td>1784852559000</td></tr><tr><td>dbfs:/Volumes/bikestore/default/bikestore/resource/origem/orders.csv</td><td>orders.csv</td><td>77286</td><td>1784852559000</td></tr><tr><td>dbfs:/Volumes/bikestore/default/bikestore/resource/origem/products.csv</td><td>products.csv</td><td>17390</td><td>1784852559000</td></tr><tr><td>dbfs:/Volumes/bikestore/default/bikestore/resource/origem/schema.png</td><td>schema.png</td><td>12013</td><td>1784852559000</td></tr><tr><td>dbfs:/Volumes/bikestore/default/bikestore/resource/origem/staffs.csv</td><td>staffs.csv</td><td>726</td><td>1784852559000</td></tr><tr><td>dbfs:/Volumes/bikestore/default/bikestore/resource/origem/stocks.csv</td><td>stocks.csv</td><td>8773</td><td>1784852559000</td></tr><tr><td>dbfs:/Volumes/bikestore/default/bikestore/resource/origem/stores.csv</td><td>stores.csv</td><td>330</td><td>1784852559000</td></tr></tbody></table></div>

# %%
#Lendo o arquivo csv
df_stocks = spark.read.format('csv')\
.option('header','true')\
.option('inferSchema','true')\
.load(resource_path + 'stocks.csv')

# %%
display(df_stocks)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>staff_id</th><th>first_name</th><th>last_name</th><th>email</th><th>phone</th><th>active</th><th>store_id</th><th>manager_id</th></tr></thead><tbody><tr><td>1</td><td>Fabiola</td><td>Jackson</td><td>fabiola.jackson@bikes.shop</td><td>(831) 555-5554</td><td>1</td><td>1</td><td>NULL</td></tr><tr><td>2</td><td>Mireya</td><td>Copeland</td><td>mireya.copeland@bikes.shop</td><td>(831) 555-5555</td><td>1</td><td>1</td><td>1</td></tr><tr><td>3</td><td>Genna</td><td>Serrano</td><td>genna.serrano@bikes.shop</td><td>(831) 555-5556</td><td>1</td><td>1</td><td>2</td></tr><tr><td>4</td><td>Virgie</td><td>Wiggins</td><td>virgie.wiggins@bikes.shop</td><td>(831) 555-5557</td><td>1</td><td>1</td><td>2</td></tr><tr><td>5</td><td>Jannette</td><td>David</td><td>jannette.david@bikes.shop</td><td>(516) 379-4444</td><td>1</td><td>2</td><td>1</td></tr><tr><td>6</td><td>Marcelene</td><td>Boyer</td><td>marcelene.boyer@bikes.shop</td><td>(516) 379-4445</td><td>1</td><td>2</td><td>5</td></tr><tr><td>7</td><td>Venita</td><td>Daniel</td><td>venita.daniel@bikes.shop</td><td>(516) 379-4446</td><td>1</td><td>2</td><td>5</td></tr><tr><td>8</td><td>Kali</td><td>Vargas</td><td>kali.vargas@bikes.shop</td><td>(972) 530-5555</td><td>1</td><td>3</td><td>1</td></tr><tr><td>9</td><td>Layla</td><td>Terrell</td><td>layla.terrell@bikes.shop</td><td>(972) 530-5556</td><td>1</td><td>3</td><td>7</td></tr><tr><td>10</td><td>Bernardine</td><td>Houston</td><td>bernardine.houston@bikes.shop</td><td>(972) 530-5557</td><td>1</td><td>3</td><td>7</td></tr></tbody></table></div>

# %%
#Gravando o arquivo parquet como delta ao caminho
df_stocks.write.mode('overwrite')\
.format('delta')\
.option('mergeSchema','true')\
.save(bronze_path + 'stocks')

# %%
#Verificando se o arquivo foi gravado
display(dbutils.fs.ls(bronze_path + 'stocks'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/bikestore/default/bikestore/bronze/staffs/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1784862539561</td></tr><tr><td>dbfs:/Volumes/bikestore/default/bikestore/bronze/staffs/part-00000-bc4fc686-55eb-4742-9fdd-40792008fc84.c000.snappy.parquet</td><td>part-00000-bc4fc686-55eb-4742-9fdd-40792008fc84.c000.snappy.parquet</td><td>3020</td><td>1784862535000</td></tr></tbody></table></div>
